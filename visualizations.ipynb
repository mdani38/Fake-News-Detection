# %%
#pip install wordcloud

# %%
#pip install Pillow

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt 
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
from wordcloud import WordCloud
from gensim.models import Word2Vec
from nltk import word_tokenize, FreqDist
import PIL
from collections import Counter
import itertools
import gc
sns.set()

# %%
df1 = pd.read_csv('fakenewsnet_kaggle/fakenewsnet/BuzzFeed_fake_news_content.csv', delimiter=',')
df1.dataframeName = 'BuzzFeed_fake_news_content.csv'

# %%
df2 = pd.read_csv('fakenewsnet_kaggle/BuzzFeed_real_news_content.csv', delimiter=',')
df2.dataframeName = 'BuzzFeed_real_news_content.csv'

# %%
df1.text.iloc[88]

# %%
df2

# %%
df3 = pd.read_csv('fakenewsnet_github/politifact_fake_updated.csv', delimiter=',')
df4 = pd.read_csv('fakenewsnet_github/politifact_real_updated.csv', delimiter=',')
df5 = pd.read_csv('fakenewsnet_github/gossipcop_fake_updated.csv', delimiter=',')
df6 = pd.read_csv('fakenewsnet_github/gossipcop_real_updated.csv', delimiter=',')

# %%
df1 =df1.dropna(subset=['title', 'text'])
df2 =df2.dropna(subset=['title', 'text'])
df3 =df3.dropna(subset=['title', 'text'])
df4 =df4.dropna(subset=['title', 'text'])
df5 =df5.dropna(subset=['title', 'text'])
df6 =df6.dropna(subset=['title', 'text'])

# %%
df1 = df1.reset_index()
df2 = df2.reset_index()
df3 = df3.reset_index()
df4 = df4.reset_index()
df5 = df5.reset_index()
df6 = df6.reset_index()

# %%
dflistreal = [df2,df4,df6]
dflistfake = [df1,df3,df5]

# %%
for df in dflistreal:
    df['target'] = 0
    df['label'] = 'Real'
for df in dflistfake:
    df['target'] = 1
    df['label'] = 'Fake'

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = df1.title
wordcloud = WordCloud(
    width = 2000,
    height = 1000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (30, 20),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.title('BuzzFeed Fake News Titles')
plt.tight_layout(pad=0)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = df1.text
wordcloud = WordCloud(
    width = 2000,
    height = 1000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (30, 20),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.title('BuzzFeed Fake News Text')
plt.tight_layout(pad=0)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = df2.title
wordcloud = WordCloud(
    width = 2000,
    height = 1000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (30, 20),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.title('BuzzFeed Real News Titles')
plt.tight_layout(pad=0)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = df2.text
wordcloud = WordCloud(
    width = 2000,
    height = 1000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (30, 20),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.title('BuzzFeed Real News Titles')
plt.tight_layout(pad=0)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = df3.title
wordcloud = WordCloud(
    width = 2000,
    height = 1000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (30, 20),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.title('Politifact Fake News Titles')
plt.tight_layout(pad=0)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = df3.text
wordcloud = WordCloud(
    width = 2000,
    height = 1000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (30, 20),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.title('Politifact Fake News Text')
plt.tight_layout(pad=0)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = df4.title
wordcloud = WordCloud(
    width = 2000,
    height = 1000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (30, 20),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.title('Politifact Real News Text')
plt.tight_layout(pad=0)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = df4.text
wordcloud = WordCloud(
    width = 2000,
    height = 1000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (30, 20),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.title('Politifact Real News Text')
plt.tight_layout(pad=0)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = df5.title
wordcloud = WordCloud(
    width = 2000,
    height = 1000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (30, 20),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.title('Gossipcop Fake News Titles')
plt.tight_layout(pad=0)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = df5.text
wordcloud = WordCloud(
    width = 2000,
    height = 1000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (30, 20),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.title('Gossipcop Fake News Text')
plt.tight_layout(pad=0)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = df6.title 
wordcloud = WordCloud(
    width = 2000,
    height = 1000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (30, 20),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.title('Gossipcop Real News Title')
plt.tight_layout(pad=0)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = df6.text 
wordcloud = WordCloud(
    width = 2000,
    height = 1000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (30, 20),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.title('Gossipcop Real News Text')
plt.tight_layout(pad=0)
plt.show()

# %%
df_merge = pd.concat([df1, df2], sort = 'False')
df_merge = pd.concat([df_merge, df3], sort = 'False')
df_merge = pd.concat([df_merge, df4], sort = 'False')
df_merge = pd.concat([df_merge, df5], sort = 'False')
df_merge = pd.concat([df_merge, df6], sort = 'False')

# %%
df_merge

# %%
df_merge = df_merge.drop(columns=['id', 'index', 'Unnamed: 0', 'level_0','summary'], axis =1)

# %%
del df1, df2, df3, df4, df5, df6;
gc.collect();

# %%
target = df_merge[['target']]
label = df_merge[['label']]

# %%
df_fake = df_merge.loc[df_merge['target'] == 1]
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = df_fake.title
wordcloud = WordCloud(
    width = 2000,
    height = 1000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (30, 20),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.title('Fake News Titles')
plt.tight_layout(pad=0)
plt.show()

# %%
df_true = df_merge.loc[df_merge['target'] == 0]
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = df_true.title
wordcloud = WordCloud(
    width = 2000,
    height = 1000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (30, 20),
    facecolor = 'k',
    edgecolor = 'k',)
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.title('Real News Titles')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
df_fake = df_merge.loc[df_merge['target'] == 1]
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = df_fake.text
wordcloud = WordCloud(
    width = 2000,
    height = 1000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (30, 20),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.title('Fake News Text')
plt.tight_layout(pad=0)
plt.show()

# %%
df_true = df_merge.loc[df_merge['target'] == 0]
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = df_true.text
wordcloud = WordCloud(
    width = 2000,
    height = 1000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (30, 20),
    facecolor = 'k',
    edgecolor = 'k',)
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.title('Real News Text')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
del df_true, df_fake;
gc.collect();

# %%
df_merge['combined_text'] = df_merge.title + ' ' + df_merge.text

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( df_merge[['combined_text']] ,target, test_size=0.20)

# %%
X_train

# %%
y_train

# %%
train = pd.concat([X_train, y_train], axis=1)
test = pd.concat([X_test, y_test], axis=1)

# %%
from pathlib import Path

import pandas as pd
import torch
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
#from google_drive_downloader import GoogleDriveDownloader as gdd
from torch.utils.data import DataLoader, Dataset
from sklearn.feature_extraction.text import CountVectorizer
from tqdm import tqdm, tqdm_notebook

# %%
class Sequences(Dataset):
    def __init__(self, path):
        df = train
        self.vectorizer = CountVectorizer(stop_words='english', max_df=0.99, min_df=0.005)
        self.sequences = self.vectorizer.fit_transform(df.combined_text.tolist())
        self.labels = df.target.tolist()
        self.token2idx = self.vectorizer.vocabulary_
        self.idx2token = {idx: token for token, idx in self.token2idx.items()}
        
    def __getitem__(self, i):
        return self.sequences[i, :].toarray(), self.labels[i]
    
    def __len__(self):
        return self.sequences.shape[0]

# %%
dataset = Sequences(train)
train_loader = DataLoader(dataset, batch_size=4096)

print(dataset[5][0].shape)

# %%
class BagOfWordsClassifier(nn.Module):
    def __init__(self, vocab_size, hidden1, hidden2):
        super(BagOfWordsClassifier, self).__init__()
        self.fc1 = nn.Linear(vocab_size, hidden1)
        self.fc2 = nn.Linear(hidden1, hidden2)
        self.fc3 = nn.Linear(hidden2, 1)
    
    def forward(self, inputs):
        x = F.relu(self.fc1(inputs.squeeze(1).float()))
        x = F.relu(self.fc2(x))
        return self.fc3(x)

# %%
model = BagOfWordsClassifier(len(dataset.token2idx), 128, 64)
model

# %%
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam([p for p in model.parameters() if p.requires_grad], lr=0.001)

# %%
model.train()
train_losses = []
for epoch in range(10):
    progress_bar = tqdm_notebook(train_loader, leave=False)
    losses = []
    total = 0
    for inputs, target in progress_bar:
        model.zero_grad()

        output = model(inputs)
        loss = criterion(output.squeeze(), target.float())
        
        loss.backward()
              
        nn.utils.clip_grad_norm_(model.parameters(), 3)

        optimizer.step()
        
        progress_bar.set_description(f'Loss: {loss.item():.3f}')
        
        losses.append(loss.item())
        total += 1
    
    epoch_loss = sum(losses) / total
    train_losses.append(epoch_loss)
        
    tqdm.write(f'Epoch #{epoch + 1}\tTrain Loss: {epoch_loss:.3f}')

# %%
def predict(text):
    model.eval()
    with torch.no_grad():
        test_vector = torch.LongTensor(dataset.vectorizer.transform([text]).toarray())

        output = model(test_vector)
        prediction = torch.sigmoid(output).item()

    return prediction

# %%
preds = []

for i in range(len(X_test)):
    prediction = predict(X_test['combined_text'].iloc[i])
    preds.append(prediction)

# %%
preds2 = pd.Series(preds)

# %%
preds2

# %%
from sklearn.metrics import accuracy_score

# %%
y_test = torch.LongTensor(dataset.vectorizer.transform(y_test).toarray())

# %%
accuracy_score(y_test, y_pred)

# %%
test_text = """
What the heck is this ? There is not one redeeming quality about this terrible
and very poorly done "movie". I can't even say that it's a "so bad it's good
movie".It is undeniably pointless to address all the things wrong here but
unfortunately even the "life lessons" about bullies and stuff like this are so
wrong and terrible that no kid should hear them.The costume is also horrible
and the acting...just unbelievable.No effort whatsoever was put into this thing
and it clearly shows,I have no idea what were they thinking or who was it even
meant for. I feel violated after watching this trash and I deeply recommend you
stay as far away as possible.This is certainly one of the worst pieces of c***
I have ever seen.
"""
predict(test_text)
